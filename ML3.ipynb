# %%
from sklearn.datasets import fetch_20newsgroups
cts = ['comp.graphics', 'comp.sys.mac.hardware', 'sci.crypt', 'sci.space']
train_data = [fetch_20newsgroups(subset='train', categories=[c]) for c in cts]
test_data = [fetch_20newsgroups(subset='test', categories=[c]) for c in cts]
# Out:
# Downloading 20news dataset. This may take a few minutes.
# Downloading dataset from https://ndownloader.figshare.com/files/5975967 (14 MB)

# %%
all_train_data = []
for d in train_data:
  all_train_data += d.data
  
all_test_data = []
for d in test_data:
  all_test_data += d.data

# %%
train_classes = []
for i in range(len(train_data)):
  train_classes += len(train_data[i].data) * [i]

test_classes = []
for i in range(len(test_data)):
  test_classes += len(test_data[i].data) * [i]

# %%
print(len(all_train_data))
print(len(train_classes))
print(len(all_test_data))
print(len(test_classes))
# Out:
# 2350
# 2350
# 1564
# 1564

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(min_df=3, max_df=0.4, max_features=1000)
X_train = cv.fit_transform(all_train_data)
X_test = cv.transform(all_test_data)

# %%
from sklearn.model_selection import GridSearchCV
def grid_search_best(model, grid, folds, grid_train_data, grid_train_classes):
  grid_search = GridSearchCV(model, param_grid=grid, cv=folds, scoring='f1_macro')
  grid_search.fit(grid_train_data, grid_train_classes) 
  return grid_search.best_score_, grid_search.best_params_, grid_search.best_estimator_

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold

n_fold = 10
stratified_folds = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=42)

models = [MultinomialNB(), 
          DecisionTreeClassifier(), 
          RandomForestClassifier()]
grids = [
{
    'alpha': [0.1, 0.5, 1, 1.5, 2],
    'fit_prior': [True, False]
},{
    'max_features': [50,100,150],
    'random_state': [42]
},{
    'n_estimators': [50,100,150],
    'max_features': [50,100,150],
    'random_state': [42]
}]

# %%
def find_models(find_models, find_grids, find_folds, find_train, find_classes):
  best_models = []
  train_scores = []
  for i in range(len(find_models)):
    score, params, estimator = grid_search_best(find_models[i], find_grids[i], find_folds, find_train.toarray(), find_classes)
    print('Best score: {}'.format(score))
    print('Best parameters: {}'.format(params))
    train_scores.append(score)
    best_models.append(estimator)
  return best_models, train_scores

# %%
best_models, train_scores = find_models(models, grids, stratified_folds, X_train, train_classes)
# Out:
# Best score: 0.9273203398561364
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.833014943440908
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.9125963885220265
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}

# %% [markdown]
# MultinomialNB: 0.9273203398561364, {'alpha': 0.1, 'fit_prior': True}
# DecisionTreeClassifier: 0.833014943440908 {'max_features': 150, 'random_state': 42}
# RandomForestClassifier: 0.9125963885220265 {'max_features': 50, 'n_estimators': 150, 'random_state': 42}

# %%
from sklearn.metrics import f1_score
def get_test_scores(models, get_test, get_classes):
  test_scores = []
  for model in models:
    preds = model.predict(get_test.toarray())
    score = f1_score(get_classes, preds, average='macro')
    test_scores.append(score)
    print(score)
  return test_scores

# %%
test_scores = get_test_scores(best_models, X_test, test_classes)
# Out:
# 0.9049165648893678
# 0.7647810545335663
# 0.8957139068057778

# %% [markdown]
# Результаты на тестовой выборке для 1 и 3 классификатора стали незначительно хуже - ~2%; для второго сильно меньше - ~7%

# %%
index_to_word = {v:k for k,v in cv.vocabulary_.items()}

# %%
def array_to_words(weights, n, index_to_word):
  features = {i:weights[i] for i in range(len(weights))}
  sorted_f = {k: v for k, v in sorted(features.items(), key=lambda item: item[1], reverse=True)}
  j = 0
  for i, v in sorted_f.items():
    j+= 1
    if j > n:
      break
    print("word: ", index_to_word[i], " \nweight: ", v)

def analyze_features(model, n, index_to_word):
  try:
    f = model.feature_importances_
    array_to_words(f, n, index_to_word)
  except AttributeError:
    for i in range(len(model.coef_)):
      print("class", i+1)
      array_to_words(model.coef_[i], n, index_to_word)
      print()

# %%
for model in best_models:
  analyze_features(model, 5, index_to_word)
  print()
# Out:
# class 1
# word:  graphics
# weight:  -4.4389539618363285
# word:  image
# weight:  -4.5658622673787
# word:  there
# weight:  -4.771725060760443
# word:  an
# weight:  -4.836094274288771
# word:  any
# weight:  -4.843509038857904
#
# class 2
# word:  mac
# weight:  -4.405462088601611
# word:  my
# weight:  -4.454147715372693
# word:  apple
# weight:  -4.533010383851667
# word:  an
# weight:  -4.738442993074061
# word:  what
# weight:  -4.84465834820678
#
# class 3
# word:  key
# weight:  -4.328001948671288
# word:  they
# weight:  -4.478830388293348
# word:  will
# weight:  -4.5022265518396445
# word:  by
# weight:  -4.582024678751
# word:  encryption
# weight:  -4.716860817758163
#
# class 4
# word:  space
# weight:  -3.882096018851964
# word:  was
# weight:  -4.452970578448493
# word:  nasa
# weight:  -4.523671392280601
# word:  by
# weight:  -4.591008562112682
# word:  they
# weight:  -4.725971416005442
#
#
# word:  space
# weight:  0.10948150477193562
# word:  encryption
# weight:  0.08669088865715406
# word:  keys
# weight:  0.07834065550654774
# word:  apple
# weight:  0.06375502995125056
# word:  clipper
# weight:  0.05100889942540983
#
# word:  space
# weight:  0.05317248509541638
# word:  clipper
# weight:  0.04199531966732335
# word:  graphics
# weight:  0.036760002272314345
# word:  apple
# weight:  0.03328712142013137
# word:  mac
# weight:  0.030667884969317945

# %% [markdown]
# В общем слова описывают тексты, однако почему-то в список попали общие слова типа 'by', 'an', 'was', 'my'. Попробуем это исправить

# %%
initial = train_scores
def get_delta(train_scores, test_scores):
  result_metric = 0
  for i in range(len(train_scores)):
    if train_scores[i] < initial[i] - 0.02:
      return 1
    delta = train_scores[i] - test_scores[i]
    result_metric += delta
  return result_metric / 3

# %%
stop_words = ['english', None]
ngram_ranges = [(1,1), (1,2), (1,3), (2,3)]
max_dfs = [0.975, 1.0]
max_features = [750, 1000, 1250]

best_cv = None
new_best_models = []
best_metric_score = get_delta(train_scores, test_scores)
for sw in stop_words:
  for nr in ngram_ranges:
    for mad in max_dfs:
      for mf in max_features:
        new_cv = CountVectorizer(stop_words = sw, ngram_range = nr, max_df=mad, max_features=mf)
        new_X_train = new_cv.fit_transform(all_train_data)
        new_X_test = new_cv.transform(all_test_data)
        curr_best_models, curr_train_scores = find_models(models, grids, stratified_folds, new_X_train, train_classes)
        curr_test_scores = get_test_scores(curr_best_models, new_X_test, test_classes)
        curr_metric_score = get_delta(curr_train_scores, curr_test_scores)
        if curr_metric_score < best_metric_score:
          best_metric_score = curr_metric_score
          new_best_models = curr_best_models
          best_cv = new_cv
# Out:
# Best score: 0.9273932981356765
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.8217130815455975
# Best parameters: {'max_features': 100, 'random_state': 42}
# Best score: 0.9105157207078907
# Best parameters: {'max_features': 50, 'n_estimators': 100, 'random_state': 42}
# 0.895081119693
# 0.7709933551653921
# 0.8796731581930259
# Best score: 0.9350708188182809
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.8283655344834668
# Best parameters: {'max_features': 100, 'random_state': 42}
# Best score: 0.918605483128324
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.9096976339898506
# 0.7688309322160573
# 0.8939045370652265
# Best score: 0.9362988720767869
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.8255661607968424
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.9223204795324964
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.9185270349949075
# 0.7825624448775597
# 0.9054868377013169
# Best score: 0.9265822695030476
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.804479815383574
# Best parameters: {'max_features': 50, 'random_state': 42}
# Best score: 0.9116292133924075
# Best parameters: {'max_features': 50, 'n_estimators': 100, 'random_state': 42}
# 0.8946740021915018
# 0.7648798544367816
# 0.8805322494239868
# Best score: 0.9325504240468556
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.824019894498376
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.9163682850178626
# Best parameters: {'max_features': 50, 'n_estimators': 50, 'random_state': 42}
# 0.9071884858805078
# 0.7985464271083862
# 0.8882869217840762
# Best score: 0.9359386139842973
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.8274675913586975
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.9240210485511169
# Best parameters: {'max_features': 50, 'n_estimators': 50, 'random_state': 42}
# 0.9154228342973656
# 0.7576461818187844
# 0.8998418630491333
# Best score: 0.9164932979902165
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.8242504208380209
# Best parameters: {'max_features': 100, 'random_state': 42}
# Best score: 0.910428685536248
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.8813177136968497
# 0.7560560448491483
# 0.891891949895456
# Best score: 0.9258844638194482
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.8353039249597736
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.9166353846533211
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.9028889459957699
# 0.7869185322597193
# 0.896079418267927
# Best score: 0.9309805047905654
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.8328105459385459
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.9227944719616612
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.9080213320866211
# 0.761704963560603
# 0.8975421032773547
# Best score: 0.9153121212798542
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.8314128710294909
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.9074455185203163
# Best parameters: {'max_features': 50, 'n_estimators': 100, 'random_state': 42}
# 0.8826199142560305
# 0.7630323644541214
# 0.8913329144248485
# Best score: 0.9267851518818639
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.8286254615801146
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.9161088532057832
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.9035361008737197
# 0.7717439690420083
# 0.8965775066474144
# Best score: 0.9271785689426514
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.8347618785708818
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.9240624930354281
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.9080510166245185
# 0.7650733057000962
# 0.8936535390278817
# Best score: 0.9139904542811463
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.8240470934654394
# Best parameters: {'max_features': 100, 'random_state': 42}
# Best score: 0.9071766664227013
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.8806559091029839
# 0.7810734900429646
# 0.8865676236129147
# Best score: 0.9250580323980031
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.83117798317898
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.9142629839375239
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.8967416504500721
# 0.8011554743724497
# 0.8898423312061293
# Best score: 0.9267605453242164
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.8294380125098548
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.9182415744826642
# Best parameters: {'max_features': 50, 'n_estimators': 100, 'random_state': 42}
# 0.9055277158783037
# 0.7793365297974256
# 0.8917421282267946
# Best score: 0.91320829989166
# Best parameters: {'alpha': 0.1, 'fit_prior': False}
# Best score: 0.8350647231092821
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.9074216689004142
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.8794903423156697
# 0.7498067631523349
# 0.886727902824137
# Best score: 0.9242549021813794
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.8457617642052495
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.9134798565517253
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.8960964299222092
# 0.7834738085946351
# 0.8820314907633716
# Best score: 0.9258882306095236
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.830225272641214
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.9182687229170053
# Best parameters: {'max_features': 50, 'n_estimators': 100, 'random_state': 42}
# 0.9073965250663345
# 0.8045357271922945
# 0.898348609973678
# Best score: 0.7775280028959601
# Best parameters: {'alpha': 0.1, 'fit_prior': False}
# Best score: 0.7350317981498989
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.7823987878720322
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.7340863813992822
# 0.6726650401141362
# 0.7515073380786786
# Best score: 0.8029541999961601
# Best parameters: {'alpha': 0.1, 'fit_prior': False}
# Best score: 0.751637574734827
# Best parameters: {'max_features': 50, 'random_state': 42}
# Best score: 0.8092065248952981
# Best parameters: {'max_features': 50, 'n_estimators': 100, 'random_state': 42}
# 0.7573876106193799
# 0.6891394135061333
# 0.775472529283019
# Best score: 0.8137758636469264
# Best parameters: {'alpha': 0.1, 'fit_prior': False}
# Best score: 0.7741511272957714
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.820040544413329
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.7731860652832014
# 0.7233988111792413
# 0.7735539646899863
# Best score: 0.7775280028959601
# Best parameters: {'alpha': 0.1, 'fit_prior': False}
# Best score: 0.7350317981498989
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.7823987878720322
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.7340863813992822
# 0.6726650401141362
# 0.7515073380786786
# Best score: 0.8029541999961601
# Best parameters: {'alpha': 0.1, 'fit_prior': False}
# Best score: 0.751637574734827
# Best parameters: {'max_features': 50, 'random_state': 42}
# Best score: 0.8092065248952981
# Best parameters: {'max_features': 50, 'n_estimators': 100, 'random_state': 42}
# 0.7573876106193799
# 0.6891394135061333
# 0.775472529283019
# Best score: 0.8137758636469264
# Best parameters: {'alpha': 0.1, 'fit_prior': False}
# Best score: 0.7741511272957714
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.820040544413329
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.7731860652832014
# 0.7233988111792413
# 0.7735539646899863
# Best score: 0.9088123064785277
# Best parameters: {'alpha': 0.1, 'fit_prior': False}
# Best score: 0.8049987718436681
# Best parameters: {'max_features': 100, 'random_state': 42}
# Best score: 0.9058131911893998
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.8842483417836339
# 0.7631838089834699
# 0.8780414146323726
# Best score: 0.9244422570629055
# Best parameters: {'alpha': 0.1, 'fit_prior': False}
# Best score: 0.814889139023304
# Best parameters: {'max_features': 100, 'random_state': 42}
# Best score: 0.914331188489589
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.899348643889321
# 0.7681334663508151
# 0.8914460359722105
# Best score: 0.9311779800946383
# Best parameters: {'alpha': 0.1, 'fit_prior': False}
# Best score: 0.8202708811276234
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.9153249838499015
# Best parameters: {'max_features': 50, 'n_estimators': 100, 'random_state': 42}
# 0.9064477088701447
# 0.7825405503581226
# 0.8983793205400292
# Best score: 0.9071439337048913
# Best parameters: {'alpha': 0.1, 'fit_prior': False}
# Best score: 0.8039279561218343
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.9058197317555259
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.8811878776834021
# 0.7472930260974779
# 0.8819679382682001
# Best score: 0.9237290374522426
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.8115364747850939
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.910779864844191
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.8981153882569447
# 0.7564406961372394
# 0.8845061088565669
# Best score: 0.930761885690554
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.7960801932223435
# Best parameters: {'max_features': 100, 'random_state': 42}
# Best score: 0.9200883261722594
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.9053071185271101
# 0.7623149810400205
# 0.8946039732889688
# Best score: 0.8889520300642231
# Best parameters: {'alpha': 0.1, 'fit_prior': False}
# Best score: 0.7941784125319303
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.9027482746520741
# Best parameters: {'max_features': 50, 'n_estimators': 100, 'random_state': 42}
# 0.8617391322858446
# 0.7436693643399698
# 0.8678326938268845
# Best score: 0.9081270526030462
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.8130898591485755
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.9056696097460227
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.8756561397411632
# 0.7582189426620319
# 0.8788980798586942
# Best score: 0.9127384600242537
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.8142641501861595
# Best parameters: {'max_features': 100, 'random_state': 42}
# Best score: 0.9138128053842127
# Best parameters: {'max_features': 50, 'n_estimators': 100, 'random_state': 42}
# 0.8827380173550854
# 0.7567787478964918
# 0.8861230569798582
# Best score: 0.8873809978026003
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.8093173871255974
# Best parameters: {'max_features': 100, 'random_state': 42}
# Best score: 0.9037181640845035
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.8585797882774832
# 0.7485411003508805
# 0.8720748834316091
# Best score: 0.9057133941758689
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.8063159156071589
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.9099959119459695
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.8732065219588634
# 0.7399775977282964
# 0.8777105452775648
# Best score: 0.9111414068527394
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.7956099705514381
# Best parameters: {'max_features': 100, 'random_state': 42}
# Best score: 0.9108376213120021
# Best parameters: {'max_features': 50, 'n_estimators': 50, 'random_state': 42}
# 0.8834567254987509
# 0.7558140228791913
# 0.8753097302156532
# Best score: 0.8859829625255534
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.7889334364744783
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.8984327667495267
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.8598218117079423
# 0.7927626316825656
# 0.8743327797833744
# Best score: 0.9051454327980825
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.7980849161738319
# Best parameters: {'max_features': 100, 'random_state': 42}
# Best score: 0.9057869904145941
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.8712507982931847
# 0.7498142499579721
# 0.8785150876996652
# Best score: 0.9110383317623694
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.8083071352845892
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.9086897760189349
# Best parameters: {'max_features': 50, 'n_estimators': 100, 'random_state': 42}
# 0.8789157641803461
# 0.7403737125689749
# 0.8794341267113908
# Best score: 0.8869719971253514
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.7995263941988158
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.9022899826813754
# Best parameters: {'max_features': 50, 'n_estimators': 100, 'random_state': 42}
# 0.8579745100835566
# 0.7525122588148471
# 0.8742397452239186
# Best score: 0.9048247715874037
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.8044072119195633
# Best parameters: {'max_features': 100, 'random_state': 42}
# Best score: 0.9059714946516527
# Best parameters: {'max_features': 50, 'n_estimators': 100, 'random_state': 42}
# 0.8701142126245365
# 0.74969245668732
# 0.8811821451855604
# Best score: 0.9103213578521488
# Best parameters: {'alpha': 0.1, 'fit_prior': True}
# Best score: 0.7976127297482385
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.9123856667220821
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.8803776962016485
# 0.7602269764435353
# 0.8881169898180827
# Best score: 0.755810869796873
# Best parameters: {'alpha': 0.1, 'fit_prior': False}
# Best score: 0.6878335403783199
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.7940838332834844
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.7254035813301625
# 0.6045919095602722
# 0.7169280695431626
# Best score: 0.792850356573817
# Best parameters: {'alpha': 0.1, 'fit_prior': False}
# Best score: 0.7008632579090297
# Best parameters: {'max_features': 100, 'random_state': 42}
# Best score: 0.8069844495716497
# Best parameters: {'max_features': 50, 'n_estimators': 100, 'random_state': 42}
# 0.7667866321245704
# 0.6460116255463497
# 0.7377392835227048
# Best score: 0.8087937285748839
# Best parameters: {'alpha': 0.1, 'fit_prior': False}
# Best score: 0.7221494731221371
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.8222955879629821
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.7609067876995959
# 0.6693446643436841
# 0.7555856614168472
# Best score: 0.755810869796873
# Best parameters: {'alpha': 0.1, 'fit_prior': False}
# Best score: 0.6878335403783199
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.7940838332834844
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.7254035813301625
# 0.6045919095602722
# 0.7169280695431626
# Best score: 0.792850356573817
# Best parameters: {'alpha': 0.1, 'fit_prior': False}
# Best score: 0.7008632579090297
# Best parameters: {'max_features': 100, 'random_state': 42}
# Best score: 0.8069844495716497
# Best parameters: {'max_features': 50, 'n_estimators': 100, 'random_state': 42}
# 0.7667866321245704
# 0.6460116255463497
# 0.7377392835227048
# Best score: 0.8087937285748839
# Best parameters: {'alpha': 0.1, 'fit_prior': False}
# Best score: 0.7221494731221371
# Best parameters: {'max_features': 150, 'random_state': 42}
# Best score: 0.8222955879629821
# Best parameters: {'max_features': 50, 'n_estimators': 150, 'random_state': 42}
# 0.7609067876995959
# 0.6693446643436841
# 0.7555856614168472

# %%
new_index_to_word = {v:k for k,v in best_cv.vocabulary_.items()}
print(new_best_models)
if len(new_best_models) > 0:
  for model in new_best_models:
    analyze_features(model, 5,new_index_to_word)
    print()
else:
  print("Couldn't find better models")
# Out:
# [MultinomialNB(alpha=0.1, class_prior=None, fit_prior=True), DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=150, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best'), RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features=50,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)]
# class 1
# word:  edu
# weight:  -3.795728592204007
# word:  lines
# weight:  -4.2705068842615
# word:  subject
# weight:  -4.302000590861929
# word:  graphics
# weight:  -4.336172480655001
# word:  organization
# weight:  -4.385368289079987
#
# class 2
# word:  edu
# weight:  -3.586220929163855
# word:  lines
# weight:  -4.159256927583651
# word:  subject
# weight:  -4.194283857213816
# word:  organization
# weight:  -4.257340988740825
# word:  mac
# weight:  -4.3073884970046965
#
# class 3
# word:  key
# weight:  -4.125860803721945
# word:  com
# weight:  -4.3575724978079835
# word:  edu
# weight:  -4.39851568444087
# word:  encryption
# weight:  -4.514719672808821
# word:  clipper
# weight:  -4.634249921078506
#
# class 4
# word:  space
# weight:  -3.7622742127129065
# word:  edu
# weight:  -3.9434393781751362
# word:  nasa
# weight:  -4.403849586141543
# word:  subject
# weight:  -4.5559447667867055
# word:  organization
# weight:  -4.586415373001433
#
#
# word:  clipper chip
# weight:  0.08872275680045183
# word:  space
# weight:  0.058373023938792214
# word:  mac
# weight:  0.0573972298697409
# word:  clipper
# weight:  0.05006995868143059
# word:  apple
# weight:  0.04171825605545681
#
# word:  space
# weight:  0.04910206712176615
# word:  clipper
# weight:  0.030405432168137975
# word:  graphics
# weight:  0.029740572543785843
# word:  apple
# weight:  0.029353802460536028
# word:  mac
# weight:  0.02929130586550459

# %% [markdown]
# Как мы видим, те слова, что были выделены выше, исчезли, но теперь первый классификатор использует похожие слова для всех классов
